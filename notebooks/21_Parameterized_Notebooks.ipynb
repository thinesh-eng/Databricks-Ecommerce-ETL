# %%
dbutils.widgets.removeAll()

dbutils.widgets.text("table_name", "silver_products")

# %%
table_name = dbutils.widgets.get("table_name")

print(f"Selected Table : {table_name}")

# %%
df = spark.table(table_name)

display(df)

# %%
print("Record Count :", df.count())

# %%
df.printSchema()

# %%
display(df.limit(10))
