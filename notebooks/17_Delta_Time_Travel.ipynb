# %%
# %sql
DESCRIBE HISTORY customer_dimension;

# %%
# %sql
SELECT *
FROM customer_dimension;

# %%
# %sql
SELECT *
FROM customer_dimension VERSION AS OF 1;

# %%
# %sql
SELECT *
FROM customer_dimension;

# %%
# %sql
SELECT *
FROM customer_dimension VERSION AS OF 1;

# %%
# %sql
SELECT *
FROM customer_dimension
TIMESTAMP AS OF '2026-07-19 10:30:00';

# %%
# %sql
SELECT COUNT(*)
FROM customer_dimension VERSION AS OF 0;

# %%
# %sql
SELECT COUNT(*)
FROM customer_dimension;

# %%
# %sql
DELETE FROM customer_dimension
WHERE customer_id = 1101;

# %%
# %sql
SELECT *
FROM customer_dimension VERSION AS OF 3
WHERE customer_id = 1101;

# %%
# %sql
RESTORE TABLE customer_dimension
TO VERSION AS OF 3;
