# %%
# %sql
SELECT *
FROM customer_dimension;

# %%
# %sql
DESCRIBE HISTORY customer_dimension;

# %%
# %sql
OPTIMIZE customer_dimension;

# %%
# %sql
DESCRIBE HISTORY customer_dimension;

# %%
# %sql
OPTIMIZE customer_dimension
ZORDER BY (customer_id);

# %%
# %sql
VACUUM customer_dimension RETAIN 168 HOURS;

# %%
# %sql
DESCRIBE HISTORY customer_dimension;

# %%
# %sql
SELECT *
FROM customer_dimension
ORDER BY customer_id;
